# %%
import pandas as pd
import os
import numpy as np

# %%
excel_table =  'funprof_geomosaic_kos.csv'
excel_table2 = 'subset_funprof_geomosaic_kos.tsv'
gthered_table = './counts/raw_counts_intersect_bp.tsv'

lista = [
"CR18_ER180415_F",
"CR18_ER180415_S",
"CR18_LE180416_F",
"CR18_LE180416_S",
"CR18_LW180405_F",
"CR18_LW180405_S",
"CR18_XF180416_F",
"CR18_XF180416_S"
]

# %%
table = pd.read_csv(excel_table, sep = ',')
print(table.head())
# Out:
#    Element        Relevance         cycle  Pathway  \
# 0  Arsenic  Biogeochemistry       Arsenic     AsOx
# 1  Arsenic  Biogeochemistry       Arsenic     AsOx
# 2  Arsenic  Biogeochemistry       Arsenic    AsRed
# 3  Arsenic  Biogeochemistry       Arsenic    AsRed
# 4   Carbon  Biogeochemistry  Fermentation  Acetate
#
#                                         pathway name  gene  \
# 0                                 Arsenite oxidation  aoxA
# 1                                 Arsenite oxidation  aoxB
# 2  Dissimilatory arsenic reduction (arsRBC or ars...  arsC
# 3  Dissimilatory arsenic reduction (arsRBC or ars...  arsC
# 4                                Mixed acid: acetate  poxB
#
#                                            gene_name key_gene energyRole  \
# 0  arsenite oxidase small subunit [EC:1.20.2.1 1....      yes          D
# 1  arsenite oxidase large subunit [EC:1.20.2.1 1....      yes          D
# 2                                 arsenate reductase      yes          A
# 3                 arsenate reductase  (glutaredoxin)      yes          A
# 4      pyruvate dehydrogenase (quinone) [EC:1.2.5.1]      NaN          D
#
#   biogeoSubstrate  Metal      KO References
# 0        Arsenite    NaN  K08355        NaN
# 1        Arsenite    NaN  K08356        NaN
# 2        Arsenate  Mo, W  K00537        NaN
# 3        Arsenate  Mo, W  K03741        NaN
# 4  Organic carbon    FAD  K00156        NaN

# %%
import math

def redox_index(acceptors_list: list, donors_list:list):
    
    num_donors = len(donors_list)
    num_acceptors = len(acceptors_list)
    
    # Compute the thoreatical maximum number of pairs 
    index = math.log(num_donors) + math.log(num_acceptors)
    # or equivalently    
    #index = math.log(num_donors * num_acceptors)
    
    return index

# %%
    
def get_KOS(working_dir:str,s:str):
    
    pckg = 'funprofiler'
    path_to_dir = os.path.join(working_dir,s,pckg)
    if os.path.exists(path_to_dir):
        table = os.path.join(path_to_dir,'prefetch_out.csv')
        results = pd.read_csv(table, sep = ',')

        ko_list = results["match_name"].str.split(':').str[1].unique().tolist()
        subset_ = results[["intersect_bp", "match_name"]]
        n_kos = len(ko_list)
    
    return n_kos,ko_list,subset_

# %%
test = pd.read_csv(excel_table2, sep = '\t'  )
print(test["Metal"])
all = []
for s in test['Metal']:
    all.append(s)
print(all)
# Out:
# 0      Fe, Mo
# 1      Fe, Mo
# 2       Mo, W
# 3       Mo, W
# 4      Ni, Fe
#         ...
# 152        //
# 153        //
# 154    Mo, Co
# 155        Fe
# 156        Fe
# Name: Metal, Length: 157, dtype: str
# ['Fe, Mo', 'Fe, Mo', 'Mo, W', 'Mo, W', 'Ni, Fe', 'Fe', 'Fe', 'Mo / W', '//', '//', '//', 'Cu', 'Cu', 'Cu', 'Cu,Fe', 'Cu,Fe', 'Cu,Fe', 'Fe-Cyt-cL', '//', 'Ln,Ca', 'FAD', 'TPP', '//', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', '//', '//', 'Fe', '//', '//', '//', '//', 'Fe', 'Ni, Fe', 'Mo, W', 'Fe', '//', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', '//', '//', '//', '//', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', '//', 'Fe', '//', 'Fe', '//', '//', 'Fe', 'Mo', 'Fe', 'Cu', 'Fe', 'Fe', 'Mo, Fe', 'Fe', '//', 'Fe', 'Fe', 'Fe', 'Cu', 'Fe', '//', 'Fe', 'Fe', 'NAD', 'Cu', 'Cu', 'Cu', 'Cu', 'Fe', 'Mo', 'Mo', 'Mg', 'Cu', 'Cu', 'Cu', 'Cu', 'Fe', 'Fe', 'Fe', '//', '//', '//', '//', '//', '//', '//', 'Fe', 'Fe', 'Fe', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Mo', '//', '//', 'Fe', 'Mo', 'Mo', 'Mo', '//', 'Fe', 'FAD', '//', '//', 'Fe', 'Fe', '//', 'Mo', '//', 'Fe', 'Ni', 'Fe', 'Fe, Mo', 'Mo', 'Fe', '//', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', '//', 'Fe', '//', 'Mo', 'Fe', 'Fe', '//', '//', 'Mo, Co', 'Fe', 'Fe']

# %%
def match_kos(unique_ko_list:list,spreadsheet:str):

    master_table = pd.read_csv(spreadsheet,sep = '\t')
    # 1. Filter Sample KOs in our master table
    detected_mask = master_table['KO'].isin(unique_ko_list)
    filtered_df = master_table[detected_mask]
    # 2. Split into UNIQUE Donors (D) and Acceptors (A)
    donors_df = filtered_df[filtered_df['energyRole'] == 'D']
    acceptors_df = filtered_df[filtered_df['energyRole'] == 'A']
    # 3. Select cofactors
    donors = set(donors_df['KO'])
    acceptors = set(acceptors_df['KO'])
    
    metal_donors = donors_df['Metal'].dropna()
    metal_acceptrs = acceptors_df['Metal'].dropna()

    raw_lists = {"acceptors": metal_acceptrs, "donors" : metal_donors}
    unique_lists = {}
    for name, lista in raw_lists.items():
        unique = []
        for row in lista:
            if isinstance(row, str) and row != '//':
                row = row.strip() 
                metals = [metal.strip() for metal in row.split(',')]
                unique.extend(metals)

        name = f'unique_{name}'
        unique_lists[name] = set(unique)

    m_a = unique_lists['unique_acceptors']
    m_d = unique_lists['unique_donors']
    print(f'Metals in acceptors: {m_a}')
    print(f'Metals in donors: {m_d}')
    
    return acceptors, donors, m_a, m_d

# %% [markdown]
# test1 = ['Fe, Mo', 'Fe, Mo', 'Mo, W', 'Mo, W', 'Ni, Fe', 'Fe', 'Fe', 'Mo / W', '//', '//', '//', 'Cu', 'Cu', 'Cu', 'Cu,Fe', 'Cu,Fe', 'Cu,Fe', 'Fe-Cyt-cL', '//', 'Ln,Ca', 'FAD', 'TPP', '//', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', '//', '//', 'Fe', '//', '//', '//', '//', 'Fe', 'Ni, Fe', 'Mo, W', 'Fe', '//', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', '//', '//', '//', '//', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', '//', 'Fe', '//', 'Fe', '//', '//', 'Fe', 'Mo', 'Fe', 'Cu', 'Fe', 'Fe', 'Mo, Fe', 'Fe', '//', 'Fe', 'Fe', 'Fe', 'Cu', 'Fe', '//', 'Fe', 'Fe', 'NAD', 'Cu', 'Cu', 'Cu', 'Cu', 'Fe', 'Mo', 'Mo', 'Mg', 'Cu', 'Cu', 'Cu', 'Cu', 'Fe', 'Fe', 'Fe', '//', '//', '//', '//', '//', '//', '//', 'Fe', 'Fe', 'Fe', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Mo', '//', '//', 'Fe', 'Mo', 'Mo', 'Mo', '//', 'Fe', 'FAD', '//', '//', 'Fe', 'Fe', '//', 'Mo', '//', 'Fe', 'Ni', 'Fe', 'Fe, Mo', 'Mo', 'Fe', '//', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', '//', 'Fe', '//', 'Mo', 'Fe', 'Fe', '//', '//', 'Mo, Co', 'Fe', 'Fe']
#
# for item in test1:
#     parts = item.replace('/', ',').split(',')
#     list = [item.strip() for item in parts if item.strip()]
#     for element in list:
#         print(element)

# %%
dictio = {}
all_A = []
all_D = []

raw_reads = pd.read_csv(gthered_table, sep = '\t')
for s in lista:

    sample_data = raw_reads[raw_reads[s] != 0][['ko_id', s]]
    kos = sample_data['ko_id'].unique()

    # #n,unique,raw_data = get_KOS(working_dir=working_dir,s=sample)
    print(f'Sample {s} has : {len(kos)} kos')
    acceptors, donors, m_a, m_d = match_kos(unique_ko_list=kos,spreadsheet=excel_table2)
    all_D.append(donors)
    all_A.append(acceptors)
    
    print(f'Acceptors: {len(acceptors)}')
    print(f'Donors: {len(donors)}')
    index_ko_pairs = redox_index(acceptors,donors)
    index_metal_pairs = redox_index(m_a,m_d)
    print("RM index:", index_ko_pairs, '\n')
    print("RP index:", index_metal_pairs, '\n')
    
    dictio[s] = {'A': acceptors, 'D' : donors}
# Out:
# Sample CR18_ER180415_F has : 5676 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Fe-Cyt-cL', 'Ca', 'Ni', 'Mo', 'Fe', 'Mg', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 47
# Donors: 44
# RM index: 7.634337235628319
#
# RP index: 4.499809670330265
#
# Sample CR18_ER180415_S has : 5158 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Ca', 'Ni', 'Mo', 'Fe', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 44
# Donors: 44
# RM index: 7.568379267836522
#
# RP index: 4.276666119016055
#
# Sample CR18_LE180416_F has : 5949 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Ni', 'Ca', 'Mo', 'Fe', 'Mg', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 50
# Donors: 45
# RM index: 7.718685495198466
#
# RP index: 4.394449154672439
#
# Sample CR18_LE180416_S has : 4793 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Ca', 'Ni', 'Mo', 'Fe', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 42
# Donors: 43
# RM index: 7.498869733976931
#
# RP index: 4.276666119016055
#
# Sample CR18_LW180405_F has : 2241 kos
# Metals in acceptors: {'Ln', 'Cu', 'Fe-Cyt-cL', 'Ni', 'Ca', 'Mo', 'Fe', 'Mg', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 35
# Donors: 29
# RM index: 6.922643891475888
#
# RP index: 4.276666119016055
#
# Sample CR18_LW180405_S has : 4591 kos
# Metals in acceptors: {'Ln', 'Cu', 'Fe-Cyt-cL', 'Ni', 'Ca', 'Mo', 'Fe', 'Mg', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 48
# Donors: 42
# RM index: 7.60887062919126
#
# RP index: 4.394449154672439
#
# Sample CR18_XF180416_F has : 5748 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Fe-Cyt-cL', 'Ca', 'Ni', 'Mo', 'Fe', 'Mg', 'W'}
# Metals in donors: {'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 53
# Donors: 42
# RM index: 7.70796153183549
#
# RP index: 4.382026634673881
#
# Sample CR18_XF180416_S has : 4922 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Fe-Cyt-cL', 'Ca', 'Ni', 'Mo', 'Fe', 'W'}
# Metals in donors: {'Co', 'Ni', 'Mo', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 42
# Donors: 41
# RM index: 7.451241684987677
#
# RP index: 4.143134726391533

# %%
print(dictio)
#INtersection
common_A = set(all_A[0]).intersection(*all_A[1:])
common_D = set(all_D[0]).intersection(*all_D[1:])
print(common_A)
print(common_D)
# ALL
all_A = set().union(*all_A)
all_D = set().union(*all_D)
print(all_A)
print(all_D)
# Out:
# {'CR18_ER180415_F': {'A': {'K00394', 'K00411', 'K14028', 'K23995', 'K00426', 'K02297', 'K00198', 'K00194', 'K03385', 'K11181', 'K07306', 'K02275', 'K00158', 'K02299', 'K00537', 'K10946', 'K00410', 'K04561', 'K04015', 'K00368', 'K02298', 'K02827', 'K00363', 'K00404', 'K00412', 'K02274', 'K15408', 'K00407', 'K15862', 'K00376', 'K03741', 'K10944', 'K14029', 'K02567', 'K15864', 'K00413', 'K00362', 'K00425', 'K17877', 'K02568', 'K11180', 'K00405', 'K02257', 'K02276', 'K00395', 'K00371', 'K00406'}, 'D': {'K21307', 'K08355', 'K00436', 'K00387', 'K00245', 'K18007', 'K00200', 'K00239', 'K02703', 'K00441', 'K00244', 'K00242', 'K00658', 'K10946', 'K17218', 'K17993', 'K16937', 'K00116', 'K00437', 'K00370', 'K14127', 'K00201', 'K00241', 'K00164', 'K06282', 'K08356', 'K17996', 'K18006', 'K18005', 'K00240', 'K21308', 'K00234', 'K14090', 'K17225', 'K17230', 'K22622', 'K10944', 'K17725', 'K15022', 'K05299', 'K10535', 'K19713', 'K00371', 'K00235'}}, 'CR18_ER180415_S': {'A': {'K00394', 'K00411', 'K23995', 'K00426', 'K02297', 'K00198', 'K00194', 'K03385', 'K11181', 'K07306', 'K02275', 'K02300', 'K00410', 'K00197', 'K02305', 'K04561', 'K00368', 'K02298', 'K02827', 'K00424', 'K00363', 'K00404', 'K00412', 'K02274', 'K15408', 'K15862', 'K00376', 'K03741', 'K10944', 'K14029', 'K02567', 'K15864', 'K00413', 'K00362', 'K00425', 'K17877', 'K02568', 'K11180', 'K00405', 'K02257', 'K02276', 'K00395', 'K00371', 'K00406'}, 'D': {'K21307', 'K08355', 'K00436', 'K00387', 'K00245', 'K18007', 'K00200', 'K00239', 'K02703', 'K00244', 'K00242', 'K14128', 'K00658', 'K05301', 'K14106', 'K17218', 'K16937', 'K00116', 'K00370', 'K14127', 'K00241', 'K00164', 'K06282', 'K08356', 'K17996', 'K18006', 'K18005', 'K11261', 'K05927', 'K00240', 'K21308', 'K00234', 'K14090', 'K17225', 'K17230', 'K22622', 'K10944', 'K17725', 'K15022', 'K05299', 'K10535', 'K19713', 'K00371', 'K00235'}}, 'CR18_LE180416_F': {'A': {'K00394', 'K00411', 'K23995', 'K20932', 'K00426', 'K02297', 'K00198', 'K03385', 'K11181', 'K07306', 'K02275', 'K02300', 'K00158', 'K02299', 'K00537', 'K10946', 'K00410', 'K02305', 'K04561', 'K00368', 'K04015', 'K00415', 'K02298', 'K02827', 'K00363', 'K00404', 'K00412', 'K02274', 'K15408', 'K00407', 'K15862', 'K00376', 'K03741', 'K10944', 'K02567', 'K15864', 'K00413', 'K00362', 'K00425', 'K17877', 'K02568', 'K11180', 'K00405', 'K00193', 'K02257', 'K02276', 'K10945', 'K00395', 'K00371', 'K00406'}, 'D': {'K21307', 'K08355', 'K00436', 'K00387', 'K21309', 'K18007', 'K00200', 'K00239', 'K00441', 'K00244', 'K00242', 'K00658', 'K05301', 'K10946', 'K17218', 'K17993', 'K16937', 'K00116', 'K00370', 'K14127', 'K00201', 'K00241', 'K00164', 'K14126', 'K20935', 'K06282', 'K08356', 'K18006', 'K18005', 'K05927', 'K00240', 'K21308', 'K00234', 'K17225', 'K17230', 'K22622', 'K10944', 'K17725', 'K15022', 'K05299', 'K10535', 'K10945', 'K19713', 'K00371', 'K00235'}}, 'CR18_LE180416_S': {'A': {'K00394', 'K00411', 'K23995', 'K20932', 'K00426', 'K02297', 'K00198', 'K00194', 'K03385', 'K11181', 'K07306', 'K02275', 'K02299', 'K00410', 'K00197', 'K02305', 'K04561', 'K00368', 'K00385', 'K02298', 'K02827', 'K00363', 'K00404', 'K00412', 'K02274', 'K15408', 'K15862', 'K00376', 'K03741', 'K02567', 'K15864', 'K00425', 'K00362', 'K17877', 'K11180', 'K00405', 'K02257', 'K02276', 'K10945', 'K00395', 'K00371', 'K00406'}, 'D': {'K21307', 'K08355', 'K05922', 'K00436', 'K00387', 'K00245', 'K18007', 'K00200', 'K21309', 'K00239', 'K00244', 'K14128', 'K00658', 'K14106', 'K17218', 'K17993', 'K16937', 'K00116', 'K00370', 'K14127', 'K00201', 'K00241', 'K00164', 'K14126', 'K20935', 'K06282', 'K18006', 'K18005', 'K11261', 'K00240', 'K21308', 'K00234', 'K14090', 'K17225', 'K17230', 'K22622', 'K17725', 'K15022', 'K05299', 'K10535', 'K10945', 'K19713', 'K00371'}}, 'CR18_LW180405_F': {'A': {'K00411', 'K14028', 'K23995', 'K00426', 'K00198', 'K00194', 'K03385', 'K11181', 'K07306', 'K02275', 'K00158', 'K10946', 'K00410', 'K00368', 'K02827', 'K00404', 'K00412', 'K02274', 'K15408', 'K15862', 'K15876', 'K00376', 'K03741', 'K10944', 'K0 ...
# {'K00411', 'K23995', 'K00426', 'K00198', 'K03385', 'K11181', 'K07306', 'K02275', 'K00410', 'K00368', 'K02827', 'K00404', 'K00412', 'K02274', 'K15408', 'K15862', 'K00376', 'K03741', 'K02567', 'K00425', 'K00362', 'K00405', 'K02257', 'K02276', 'K00395', 'K00371', 'K11180'}
# {'K21307', 'K08355', 'K00436', 'K18007', 'K00200', 'K00239', 'K00244', 'K00658', 'K17218', 'K00370', 'K14127', 'K00164', 'K06282', 'K18005', 'K00240', 'K00234', 'K17225', 'K17230', 'K15022', 'K05299', 'K10535', 'K19713', 'K00371'}
# {'K00394', 'K00411', 'K00417', 'K16158', 'K02297', 'K03385', 'K02275', 'K00158', 'K10946', 'K00415', 'K00368', 'K00385', 'K02298', 'K00424', 'K00363', 'K02274', 'K15408', 'K15862', 'K14029', 'K02567', 'K15864', 'K00413', 'K00362', 'K00425', 'K02568', 'K00405', 'K00193', 'K10945', 'K00395', 'K11180', 'K14028', 'K23995', 'K00426', 'K20932', 'K00198', 'K00194', 'K11181', 'K07306', 'K02300', 'K02299', 'K00537', 'K02826', 'K00410', 'K00197', 'K02305', 'K04561', 'K04015', 'K02827', 'K00404', 'K00412', 'K02277', 'K00407', 'K15876', 'K00376', 'K16951', 'K03741', 'K10944', 'K17877', 'K02257', 'K02276', 'K00371', 'K00406'}
# {'K08355', 'K05922', 'K00436', 'K00245', 'K00200', 'K00239', 'K02703', 'K18277', 'K00244', 'K00242', 'K14128', 'K00658', 'K05301', 'K10946', 'K14106', 'K00116', 'K00437', 'K14127', 'K00201', 'K00164', 'K20935', 'K08356', 'K17996', 'K18005', 'K05927', 'K21308', 'K14090', 'K22622', 'K05299', 'K10945', 'K19713', 'K21307', 'K00387', 'K21309', 'K18007', 'K00441', 'K17218', 'K17993', 'K16937', 'K00370', 'K00241', 'K14126', 'K06282', 'K18006', 'K11261', 'K00240', 'K00234', 'K16965', 'K17225', 'K17230', 'K10944', 'K17725', 'K15022', 'K00236', 'K14087', 'K10535', 'K00371', 'K00235'}

# %%
for item in common_A:
    print(item)
# Out:
# K00411
# K23995
# K00426
# K00198
# K03385
# K11181
# K07306
# K02275
# K00410
# K00368
# K02827
# K00404
# K00412
# K02274
# K15408
# K15862
# K00376
# K03741
# K02567
# K00425
# K00362
# K00405
# K02257
# K02276
# K00395
# K00371
# K11180

# %%
#ACCEPTORS
dsr = ["K11180","K11181","K27187"] #dsrA,B,gamma
DMSORed = ['K00184', 'K00185', 'K07306', 'K07307', 'K07308', 'K16964']
#DONors
hyd = ['K17993', 'K17994', 'K17995', 'K17996'] #Sulfhydrogenase, (sulfide)n -> (sulfide)n-1 #NOT fo

# %%
#item = "K11180"
for item in hyd:
    if item in all_D:
        print(item)
# Out:
# K17993
# K17996
