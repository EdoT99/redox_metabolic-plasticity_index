# %%
import pandas as pd
import os
import numpy as np

# %%
excel_table =  'funprof_geomosaic_kos.csv'
excel_table2 = 'subset_funprof_geomosaic_kos.tsv'
gthered_table = './counts/raw_counts_intersect_bp.tsv'

lista = [
"CR18_ER180415_F",
"CR18_ER180415_S",
"CR18_LE180416_F",
"CR18_LE180416_S",
"CR18_LW180405_F",
"CR18_LW180405_S",
"CR18_XF180416_F",
"CR18_XF180416_S"
]

# %%
table = pd.read_csv(excel_table, sep = ',')
print(table.head())
# Out:
#    Element        Relevance         cycle  Pathway  \
# 0  Arsenic  Biogeochemistry       Arsenic     AsOx
# 1  Arsenic  Biogeochemistry       Arsenic     AsOx
# 2  Arsenic  Biogeochemistry       Arsenic    AsRed
# 3  Arsenic  Biogeochemistry       Arsenic    AsRed
# 4   Carbon  Biogeochemistry  Fermentation  Acetate
#
#                                         pathway name  gene  \
# 0                                 Arsenite oxidation  aoxA
# 1                                 Arsenite oxidation  aoxB
# 2  Dissimilatory arsenic reduction (arsRBC or ars...  arsC
# 3  Dissimilatory arsenic reduction (arsRBC or ars...  arsC
# 4                                Mixed acid: acetate  poxB
#
#                                            gene_name key_gene energyRole  \
# 0  arsenite oxidase small subunit [EC:1.20.2.1 1....      yes          D
# 1  arsenite oxidase large subunit [EC:1.20.2.1 1....      yes          D
# 2                                 arsenate reductase      yes          A
# ...

# %%
import math

def redox_index(acceptors_list: list, donors_list:list):
    
    num_donors = len(donors_list)
    num_acceptors = len(acceptors_list)
    
    # Compute the thoreatical maximum number of pairs 
    index = math.log(num_donors) + math.log(num_acceptors)
    # or equivalently    
    #index = math.log(num_donors * num_acceptors)
    
    return index

# %%
    
def get_KOS(working_dir:str,s:str):
    
    pckg = 'funprofiler'
    path_to_dir = os.path.join(working_dir,s,pckg)
    if os.path.exists(path_to_dir):
        table = os.path.join(path_to_dir,'prefetch_out.csv')
        results = pd.read_csv(table, sep = ',')

        ko_list = results["match_name"].str.split(':').str[1].unique().tolist()
        subset_ = results[["intersect_bp", "match_name"]]
        n_kos = len(ko_list)
    
    return n_kos,ko_list,subset_

# %%
test = pd.read_csv(excel_table2, sep = '\t'  )
print(test["Metal"])
all = []
for s in test['Metal']:
    all.append(s)
print(all)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 test = pd.read_csv(excel_table2, sep = '\t'  )
#       2 print(test["Metal"])
#       3 all = []
#
# ...

# %%
def match_kos(unique_ko_list:list,spreadsheet:str):

    master_table = pd.read_csv(spreadsheet,sep = '\t')
    # 1. Filter Sample KOs in our master table
    detected_mask = master_table['KO'].isin(unique_ko_list)
    filtered_df = master_table[detected_mask]
    # 2. Split into UNIQUE Donors (D) and Acceptors (A)
    donors_df = filtered_df[filtered_df['energyRole'] == 'D']
    acceptors_df = filtered_df[filtered_df['energyRole'] == 'A']
    # 3. Select cofactors
    donors = set(donors_df['KO'])
    acceptors = set(acceptors_df['KO'])
    
    metal_donors = donors_df['Metal'].dropna()
    metal_acceptrs = acceptors_df['Metal'].dropna()

    raw_lists = {"acceptors": metal_acceptrs, "donors" : metal_donors}
    unique_lists = {}
    for name, lista in raw_lists.items():
        unique = []
        for row in lista:
            if isinstance(row, str) and row != '//':
                row = row.strip() 
                metals = [metal.strip() for metal in row.split(',')]
                unique.extend(metals)

        name = f'unique_{name}'
        unique_lists[name] = set(unique)

    m_a = unique_lists['unique_acceptors']
    m_d = unique_lists['unique_donors']
    print(f'Metals in acceptors: {m_a}')
    print(f'Metals in donors: {m_d}')
    
    return acceptors, donors, m_a, m_d

# %% [markdown]
# test1 = ['Fe, Mo', 'Fe, Mo', 'Mo, W', 'Mo, W', 'Ni, Fe', 'Fe', 'Fe', 'Mo / W', '//', '//', '//', 'Cu', 'Cu', 'Cu', 'Cu,Fe', 'Cu,Fe', 'Cu,Fe', 'Fe-Cyt-cL', '//', 'Ln,Ca', 'FAD', 'TPP', '//', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', '//', '//', 'Fe', '//', '//', '//', '//', 'Fe', 'Ni, Fe', 'Mo, W', 'Fe', '//', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', '//', '//', '//', '//', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', 'Ni, Fe', '//', 'Fe', '//', 'Fe', '//', '//', 'Fe', 'Mo', 'Fe', 'Cu', 'Fe', 'Fe', 'Mo, Fe', 'Fe', '//', 'Fe', 'Fe', 'Fe', 'Cu', 'Fe', '//', 'Fe', 'Fe', 'NAD', 'Cu', 'Cu', 'Cu', 'Cu', 'Fe', 'Mo', 'Mo', 'Mg', 'Cu', 'Cu', 'Cu', 'Cu', 'Fe', 'Fe', 'Fe', '//', '//', '//', '//', '//', '//', '//', 'Fe', 'Fe', 'Fe', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Cu', 'Mo', '//', '//', 'Fe', 'Mo', 'Mo', 'Mo', '//', 'Fe', 'FAD', '//', '//', 'Fe', 'Fe', '//', 'Mo', '//', 'Fe', 'Ni', 'Fe', 'Fe, Mo', 'Mo', 'Fe', '//', 'Fe', 'Fe', 'Fe', 'Fe', 'Fe', '//', 'Fe', '//', 'Mo', 'Fe', 'Fe', '//', '//', 'Mo, Co', 'Fe', 'Fe']
#
# for item in test1:
#     parts = item.replace('/', ',').split(',')
#     list = [item.strip() for item in parts if item.strip()]
#     for element in list:
#         print(element)

# %%
dictio = {}
all_A = []
all_D = []

raw_reads = pd.read_csv(gthered_table, sep = '\t')
for s in lista:

    sample_data = raw_reads[raw_reads[s] != 0][['ko_id', s]]
    kos = sample_data['ko_id'].unique()

    # #n,unique,raw_data = get_KOS(working_dir=working_dir,s=sample)
    print(f'Sample {s} has : {len(kos)} kos')
    acceptors, donors, m_a, m_d = match_kos(unique_ko_list=kos,spreadsheet=excel_table2)
    all_D.append(donors)
    all_A.append(acceptors)
    
    print(f'Acceptors: {len(acceptors)}')
    print(f'Donors: {len(donors)}')
    index_ko_pairs = redox_index(acceptors,donors)
    index_metal_pairs = redox_index(m_a,m_d)
    print("RM index:", index_ko_pairs, '\n')
    print("RP index:", index_metal_pairs, '\n')
    
    dictio[s] = {'A': acceptors, 'D' : donors}
# Out:
# Sample CR18_ER180415_F has : 5676 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Fe-Cyt-cL', 'Ca', 'Ni', 'Mo', 'Fe', 'Mg', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 47
# Donors: 44
# RM index: 7.634337235628319
#
# RP index: 4.499809670330265
#
# Sample CR18_ER180415_S has : 5158 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Ca', 'Ni', 'Mo', 'Fe', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 44
# Donors: 44
# RM index: 7.568379267836522
#
# RP index: 4.276666119016055
#
# Sample CR18_LE180416_F has : 5949 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Ni', 'Ca', 'Mo', 'Fe', 'Mg', 'W'}
# Metals in donors: {'Cu', 'Co', 'Ni', 'Mo', 'FAD', 'Fe', 'TPP', 'Mo / W', 'W'}
# Acceptors: 50
# Donors: 45
# RM index: 7.718685495198466
#
# RP index: 4.394449154672439
#
# Sample CR18_LE180416_S has : 4793 kos
# Metals in acceptors: {'Ln', 'Cu', 'NAD', 'Ca', 'Ni', 'Mo', 'Fe', 'W'}
# ...

# %%
print(dictio)
#INtersection
common_A = set(all_A[0]).intersection(*all_A[1:])
common_D = set(all_D[0]).intersection(*all_D[1:])
print(common_A)
print(common_D)
# ALL
all_A = set().union(*all_A)
all_D = set().union(*all_D)
print(all_A)
print(all_D)
# Out:
# {'CR18_ER180415_F': {'A': {'K00394', 'K00411', 'K14028', 'K23995', 'K00426', 'K02297', 'K00198', 'K00194', 'K03385', 'K11181', 'K07306', 'K02275', 'K00158', 'K02299', 'K00537', 'K10946', 'K00410', 'K04561', 'K04015', 'K00368', 'K02298', 'K02827', 'K00363', 'K00404', 'K00412', 'K02274', 'K15408', 'K00407', 'K15862', 'K00376', 'K03741', 'K10944', 'K14029', 'K02567', 'K15864', 'K00413', 'K00362', 'K00425', 'K17877', 'K02568', 'K11180', 'K00405', 'K02257', 'K02276', 'K00395', 'K00371', 'K00406'}, 'D': {'K21307', 'K08355', 'K00436', 'K00387', 'K00245', 'K18007', 'K00200', 'K00239', 'K02703', 'K00441', 'K00244', 'K00242', 'K00658', 'K10946', 'K17218', 'K17993', 'K16937', 'K00116', 'K00437', 'K00370', 'K14127', 'K00201', 'K00241', 'K00164', 'K06282', 'K08356', 'K17996', 'K18006', 'K18005', 'K00240', 'K21308', 'K00234', 'K14090', 'K17225', 'K17230', 'K22622', 'K10944', 'K17725', 'K15022', 'K05299', 'K10535', 'K19713', 'K00371', 'K00235'}}, 'CR18_ER180415_S': {'A': {'K00394', 'K00411', 'K2399
# ...

# %%
for item in common_A:
    print(item)
# Out:
# K00411
# K23995
# K00426
# K00198
# K03385
# K11181
# K07306
# K02275
# K00410
# K00368
# K02827
# K00404
# K00412
# K02274
# K15408
# K15862
# K00376
# K03741
# K02567
# K00425
# K00362
# K00405
# K02257
# K02276
# K00395
# K00371
# K11180

# %%
#ACCEPTORS
dsr = ["K11180","K11181","K27187"] #dsrA,B,gamma
DMSORed = ['K00184', 'K00185', 'K07306', 'K07307', 'K07308', 'K16964']
#DONors
hyd = ['K17993', 'K17994', 'K17995', 'K17996'] #Sulfhydrogenase, (sulfide)n -> (sulfide)n-1 #NOT fo

# %%
#item = "K11180"
for item in hyd:
    if item in all_D:
        print(item)
# Out:
# K17993
# K17996

# %%
import pandas as pd
data_frame = pd.read_csv(gthered_table, sep='\t')
#print(data_frame.iloc[:5,:])
selected_df = data_frame[['ko_id','CR18_ER180415_F']]

print(selected_df.iloc[:5,:])
sample = sample = data_frame.columns[1]
print(sample)
# Out:
#     ko_id  CR18_ER180415_F
# 0  K00001          11000.0
# 1  K00002              0.0
# 2  K00003          36000.0
# 3  K00004          13000.0
# 4  K00005           1000.0
# CR18_ER180415_F

# %%
raw_counts = './counts/prefetch_out.csv'

# %%
import os
import pandas as pd
import math


def redox_index(acceptors_list: list, donors_list:list) -> float:
    num_donors = len(donors_list)
    num_acceptors = len(acceptors_list)
    if num_donors == 0 or num_acceptors == 0:
        return 0.0
    return float(round(math.log(num_donors) + math.log(num_acceptors),4))


def substrate_metal_map(df: pd.DataFrame) -> tuple[dict[str, set], list[str]]:
    substrate_map = {}
    unique_metals = set()
    
    for _, row in df.iterrows():
        substrate = row['biogeoSubstrate']
        metal = row['Metal']
        if pd.isna(substrate):
            continue
        if substrate not in substrate_map:
            substrate_map[substrate] = set()
        if isinstance(metal, str) and metal != '//':
            metals = [m.strip() for m in metal.split(',')]
            substrate_map[substrate].update(metals)

    for sub, metals in substrate_map.items():
        unique_metals.update(metals)

    return substrate_map, list(unique_metals)

#raw_ko_file = str()
spreadsheet = "./subset_funprof_geomosaic_new.tsv"

results = pd.read_csv(raw_counts, sep = ',')
ko_list = results["match_name"].str.split(':').str[1].unique().tolist()
subset_ = results[["intersect_bp", "match_name"]]

n_kos = len(ko_list)
# 1. Filter Sample KOs in our master table
biogeochem_table = pd.read_csv(spreadsheet,sep = '\t')
filtered_df = biogeochem_table[biogeochem_table['KO'].isin(ko_list)]

# 2. Split into UNIQUE Donors (D) and Acceptors (A)
donors_df = filtered_df[filtered_df['energyRole'] == 'D']
acceptors_df = filtered_df[filtered_df['energyRole'] == 'A']

# 3. Select Donors / Acceptors
donors = set(donors_df['KO'])
acceptors = set(acceptors_df['KO'])

print(len(donors))
print(len(acceptors))
# 3.2 Select Donors and Acceptors
unique_donors = donors_df['biogeoSubstrate'].dropna().unique().tolist()
unique_acceptors = acceptors_df['biogeoSubstrate'].dropna().unique().tolist()


# 3.1 SELECT substrates and their metals
# Given a lsit of Donors/Acceptirs KO, get all the biogesubstrates in dataframe associted to those KO

donors_subs, unique_donor_metals = substrate_metal_map(donors_df)
acceptors_subs , unique_acceptor_metals = substrate_metal_map(acceptors_df)

print(len(unique_donor_metals))
print(len(unique_acceptor_metals))


print(len(unique_donors))
print(len(unique_acceptors))

# print(len(donors_subs_metals))
# print(len(acceptors_subs_metals))
# print(donors_subs_metals)
# print(acceptors_subs_metals)

index_substrate_pairs = redox_index(unique_acceptors,unique_donors)
index_metal_pairs = redox_index(unique_acceptor_metals,unique_donor_metals)

def parse_results(s, d, index_substrate_pairs, index_metal_pairs, type_s):
    rows = []
    for substrate, metals in d.items():
        if metals:  # skip empty sets like 'Water'
            for metal in metals:
                rows.append({'sample': s, 'rmi' : index_substrate_pairs, 'rpi' : index_metal_pairs, 'substrate' : substrate, 'metal': metal, 'type' : type_s})
    
    return pd.DataFrame(rows)


results_donors = parse_results(sample,donors_subs, index_metal_pairs, index_substrate_pairs,type_s='donors')
results_acceptors = parse_results(sample,acceptors_subs, index_metal_pairs, index_substrate_pairs, type_s='acceptors')

df_ext = pd.concat([results_donors, results_acceptors], ignore_index=True)

out_file_extended = os.path.join(str('./meta_index_output_extended.tsv'))
df_ext.to_csv(out_file_extended, sep='\t', index=False)

out_file_truncated = os.path.join(str('./meta_index_output.tsv'))
df_trunc = pd.DataFrame({
    'sample': [sample],
    'redox-metabolic-index': [index_substrate_pairs],
    'redox-plasticty-index': [index_metal_pairs],
    'acceptors_metals': str(unique_acceptor_metals),
    'donors_metal': str(unique_donor_metals),
    'acceptor_substrates': str(unique_acceptors),
    'donor_substrates': str(donors_subs)
})
df_trunc.to_csv(out_file_truncated, sep='\t', index=False)

print(index_ko_pairs)
print(index_metal_pairs)
# Out:
# 44
# 47
# 6
# 8
# 12
# 12
# 4.9698
# 3.8712

# %%
#deconvolute the output to as many rows as there are metals
print(results_acceptors)
# Out:
#              sample     rmi     rpi        substrate metal       type
# 0   CR18_ER180415_F  3.8712  4.9698         Arsenate     W  acceptors
# 1   CR18_ER180415_F  3.8712  4.9698         Arsenate    Mo  acceptors
# 2   CR18_ER180415_F  3.8712  4.9698              CO2    Ni  acceptors
# 3   CR18_ER180415_F  3.8712  4.9698              CO2    Fe  acceptors
# 4   CR18_ER180415_F  3.8712  4.9698  Ammonia/Methane    Cu  acceptors
# 5   CR18_ER180415_F  3.8712  4.9698         Methanol    Ln  acceptors
# 6   CR18_ER180415_F  3.8712  4.9698         Methanol    Fe  acceptors
# 7   CR18_ER180415_F  3.8712  4.9698         Methanol    Ca  acceptors
# 8   CR18_ER180415_F  3.8712  4.9698          Nitrite    Cu  acceptors
# 9   CR18_ER180415_F  3.8712  4.9698          Nitrite    Fe  acceptors
# 10  CR18_ER180415_F  3.8712  4.9698          Nitrate    Fe  acceptors
# 11  CR18_ER180415_F  3.8712  4.9698          Nitrate    Mo  acceptors
# ...

# %%
out_file_truncated = os.path.join(str('./meta_index_output.tsv'))
df_trunc = pd.DataFrame({
    'sample': [sample],
    'redox-metabolic-index': [index_ko_pairs],
    'redox-plasticty-index': [index_metal_pairs]
})
df_trunc.to_csv(out_file_truncated, sep='\t', index=False)

out_file_extended = os.path.join(str('./meta_index_output.tsv'))
df_ext = pd.DataFrame({
    'sample': [sample],
    'redox-metabolic-index': [index_ko_pairs],
    'redox-plasticty-index': [index_metal_pairs],
    'A_metal': str(m_a),
    'D_metal': str(m_d),
    'A_substrate': str(unique_acceptors),
    'D_substrate': str(unique_donors)
})
df_ext.to_csv(out_file_extended, sep='\t', index=False)
